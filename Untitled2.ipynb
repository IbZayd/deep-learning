# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

fun= pd.read_csv('./fundamentals.csv', index_col=0)
fun
# Out:
#      Ticker Symbol Period Ending  Accounts Payable  Accounts Receivable  \
# 0              AAL    2012-12-31      3.068000e+09         -222000000.0
# 1              AAL    2013-12-31      4.975000e+09          -93000000.0
# 2              AAL    2014-12-31      4.668000e+09         -160000000.0
# 3              AAL    2015-12-31      5.102000e+09          352000000.0
# 4              AAP    2012-12-29      2.409453e+09          -89482000.0
# ...            ...           ...               ...                  ...
# 1776          ZION    2015-12-31      0.000000e+00                  0.0
# 1777           ZTS    2013-12-31      1.381000e+09          -99000000.0
# 1778           ZTS    2014-12-31      1.071000e+09           69000000.0
# 1779           ZTS    2015-12-31      1.313000e+09          -58000000.0
# 1780           ZTS    2016-12-31      1.076000e+09           15000000.0
#
#       Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# ...

# %%
tick = pd.DataFrame(fun, columns=['Ticker Symbol', 'Period Ending','Total Revenue'])

tick
# Out:
#      Ticker Symbol Period Ending  Total Revenue
# 0              AAL    2012-12-31   2.485500e+10
# 1              AAL    2013-12-31   2.674300e+10
# 2              AAL    2014-12-31   4.265000e+10
# 3              AAL    2015-12-31   4.099000e+10
# 4              AAP    2012-12-29   6.205003e+09
# ...            ...           ...            ...
# 1776          ZION    2015-12-31   2.210591e+09
# 1777           ZTS    2013-12-31   4.561000e+09
# 1778           ZTS    2014-12-31   4.785000e+09
# 1779           ZTS    2015-12-31   4.765000e+09
# 1780           ZTS    2016-12-31   4.888000e+09
#
# [1781 rows x 3 columns]

# %%
new_tick= tick.iloc[190:200]

new_tick
# Out:
#     Ticker Symbol Period Ending  Total Revenue
# 190           BAC    2012-12-31   1.000780e+11
# 191           BAC    2013-12-31   1.016970e+11
# 192           BAC    2014-12-31   9.518100e+10
# 193           BAC    2015-12-31   9.305600e+10
# 194           BAX    2012-12-31   1.393600e+10
# 195           BAX    2013-12-31   9.413000e+09
# 196           BAX    2014-12-31   1.071900e+10
# 197           BAX    2015-12-31   9.968000e+09
# 198          BBBY    2013-03-02   1.091458e+10
# 199          BBBY    2014-03-01   1.150396e+10

# %%
labels= 'Ticker Symbol'
friends= 'Period Ending'
minutes= 'Total Revenue'

plt.scatter(friends, minutes)
for lvalues in zip(labels, friends, minutes):
    plt.annotate(label,
    xy=(friends, minutes), # Put the label with its point
    xytext=(5, -5), # but slightly offset
    textcoords='offset points')
plt.title("new_t")
plt.xlabel("Period Ending")
plt.ylabel("Total Revenue")
plt.show()

# %%
sns.boxplot(x='Ticker Symbol', y='Total Revenue', palette=['m','g'], data=new_tick)
# Out:
# <AxesSubplot:xlabel='Ticker Symbol', ylabel='Total Revenue'>

# %% [markdown]
# #in the year 2012, BAX seem to be the one with the most revenue.
# #in 2013, BAX has the highest revenue.
# #in 2014, BAC has the highest revenue.
# #in 2015, BAX has the highest revenue.
#
# # I have issues understanding the value of e in the Total Revenue column
